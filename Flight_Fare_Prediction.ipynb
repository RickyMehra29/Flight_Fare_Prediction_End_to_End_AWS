# %% [markdown]
# ## Flight Fare Prediction -- Regression

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel('\Flight_Fare_Prediction_Data.xlsx')
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.shape
# Out:
# (10683, 11)

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
def detail_info(data):
    temp_df = pd.DataFrame(index= data.columns)
    
    temp_df['data_type'] = data.dtypes
    temp_df['unique_val'] = data.nunique()
    temp_df['duplicate_val'] = data.duplicated().sum()
    temp_df['missing_val'] = data.isnull().sum()
    temp_df['missing_val_%'] = round(data.isnull().mean()*100,2)
    
    return temp_df

# %%
detail_info(df)
# Out:
#                 data_type  unique_val  duplicate_val  missing_val  \
# Airline            object          12            220            0
# Date_of_Journey    object          44            220            0
# Source             object           5            220            0
# Destination        object           6            220            0
# Route              object         128            220            1
# Dep_Time           object         222            220            0
# Arrival_Time       object        1343            220            0
# Duration           object         368            220            0
# Total_Stops        object           5            220            1
# Additional_Info    object          10            220            0
# Price               int64        1870            220            0
#
#                  missing_val_%
# Airline                   0.00
# Date_of_Journey           0.00
# Source                    0.00
# Destination               0.00
# Route                     0.01
# Dep_Time                  0.00
# Arrival_Time              0.00
# Duration                  0.00
# Total_Stops               0.01
# Additional_Info           0.00
# Price                     0.00

# %% [markdown]
# ### Observation:
#
# * There are two missing values in Route and Total_Stops features & 220 Duplicate records.

# %%
df[df['Route'].isnull()==True]

# Since there is only one record, we may delete the row
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 9039  09:25 07 May  23h 40m         NaN         No info   7480

# %%
df.dropna(inplace=True)
df.reset_index(drop=True)
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 0                 IndiGo      24/03/2019  Banglore   New Delhi
# 1              Air India       1/05/2019   Kolkata    Banglore
# 2            Jet Airways       9/06/2019     Delhi      Cochin
# 3                 IndiGo      12/05/2019   Kolkata    Banglore
# 4                 IndiGo      01/03/2019  Banglore   New Delhi
# 5               SpiceJet      24/06/2019   Kolkata    Banglore
# 6            Jet Airways      12/03/2019  Banglore   New Delhi
# 7            Jet Airways      01/03/2019  Banglore   New Delhi
# 8            Jet Airways      12/03/2019  Banglore   New Delhi
# 9      Multiple carriers      27/05/2019     Delhi      Cochin
# 10             Air India       1/06/2019     Delhi      Cochin
# 11                IndiGo      18/04/2019   Kolkata    Banglore
# 12             Air India      24/06/2019   Chennai     Kolkata
# 13           Jet Airways       9/05/2019   Kolkata    Banglore
# 14                IndiGo      24/04/2019   Kolkata    Banglore
# 15             Air India       3/03/2019     Delhi      Cochin
# 16              SpiceJet      15/04/2019     Delhi      Cochin
# 17           Jet Airways      12/06/2019     Delhi      Cochin
# 18             Air India      12/06/2019     Delhi      Cochin
# 19           Jet Airways      27/05/2019     Delhi      Cochin
# 20                 GoAir       6/03/2019     Delhi      Cochin
# 21             Air India      21/03/2019  Banglore   New Delhi
# 22                IndiGo       3/04/2019  Banglore       Delhi
# 23                IndiGo       1/05/2019  Banglore       Delhi
# 24           Jet Airways       6/05/2019   Kolkata    Banglore
# 25           Jet Airways       9/06/2019     Delhi      Cochin
# 26                IndiGo       1/06/2019     Delhi      Cochin
# 27                 GoAir      15/05/2019     Delhi      Cochin
# 28               Vistara      18/06/2019  Banglore       Delhi
# 29               Vistara      15/06/2019   Chennai     Kolkata
# ...                  ...             ...       ...         ...
# 10652        Jet Airways       1/05/2019   Kolkata    Banglore
# 10653           SpiceJet      12/06/2019  Banglore       Delhi
# 10654        Jet Airways       3/05/2019    Mumbai   Hyderabad
# 10655            Vistara       6/04/2019  Banglore       Delhi
# 10656        Jet Airways       6/05/2019   Kolkata    Banglore
# 10657        Jet Airways      18/06/2019  Banglore       Delhi
# 10658            Vistara       1/05/2019  Banglore       Delhi
# 10659            Vistara      21/03/2019  Banglore   New Delhi
# 10660          Air India       9/05/2019     Delhi      Cochin
# 10661          Air India      24/03/2019   Kolkata    Banglore
# 10662        Jet Airways       6/06/2019     Delhi      Cochin
# 10663             IndiGo       9/04/2019  Banglore       Delhi
# 10664             IndiGo      27/04/2019   Kolkata    Banglore
# 10665        Jet Airways      12/06/2019     Delhi      Cochin
# 10666        Jet Airways      12/03/2019  Banglore   New Delhi
# 10667        Jet Airways       9/05/2019     Delhi      Cochin
# 10668          Air India      15/06/2019     Delhi      Cochin
# 10669          Air India      12/05/2019   Kolkata    Banglore
# 10670          Air India       6/06/2019    Mumbai   Hyderabad
# 10671        Jet Airways      27/06/2019     Delhi      Cochin
# 10672        Jet Airways      27/05/2019     Delhi      Cochin
# 10673        Jet Airways      12/03/2019  Banglore   New Delhi
# 10674          Air India       9/06/2019    Mumbai   Hyderabad
# 10675  Multiple carriers       1/05/2019     Delhi      Cochin
# 10676           SpiceJet      21/05/2019  Banglore       Delhi
# 10677           Air Asia       9/04/2019   Kolkata    Banglore
# 10678          Air India      27/04/2019   Kolkata    Banglore
# 10679        Jet Airways      27/04/2019  Banglore       Delhi
# 10680            Vistara      01/03/2019  Banglore   New Delhi
# 10681          Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# 5                  CCU → BLR    09:00         11:25   2h 25m    non-stop
# 6            BLR → BOM → DEL    18:55  10:25 13 Mar  15h 30m      1 stop
# 7            BLR → BOM → DEL    08:00  05:05 02 Mar   21h 5m      1 stop
# 8            BLR → BOM → DEL    08:55  10:25 13 Mar  25h 30m      1 stop
# 9            DEL → BOM → COK    11:25         19:15   7h 50m      1 stop
# 10           DEL → BLR → COK    09:45         23:00  13h 15m      1 stop
# 11                 CCU → BLR    20:20         22:55   2h 35m    non-stop
# 12                 MAA → CCU    11:40         13:55   2h 15m    non-stop
# 13           CCU → BOM → BLR    21:10  09:20 10 May  12h 10m      1 stop
# 14                 CCU → BLR    17:15         19:50   2h 35m    non-stop
# 15     DEL → AMD → BOM → COK    16:40  19:15 04 Mar  26h 35m     2 stops
# 16           DEL → PNQ → COK    08:45         13:15   4h 30m      1 stop
# 17           DEL → BOM → COK    14:00  12:35 13 Jun  22h 35m      1 stop
# 18     DEL → CCU → BOM → COK    20:15  19:15 13 Jun      23h     2 stops
# 19           DEL → BOM → COK    16:00  12:35 28 May  20h 35m      1 stop
# 20           DEL → BOM → COK    14:10         19:20   5h 10m      1 stop
# 21           BLR → COK → DEL    22:00  13:20 19 Mar  15h 20m      1 stop
# 22                 BLR → DEL    04:00         06:50   2h 50m    non-stop
# 23                 BLR → DEL    18:55         21:50   2h 55m    non-stop
# 24           CCU → BOM → BLR    18:55  08:15 07 May  13h 20m      1 stop
# 25     DEL → IDR → BOM → COK    21:25  12:35 10 Jun  15h 10m     2 stops
# 26           DEL → LKO → COK    21:50  03:35 02 Jun   5h 45m      1 stop
# 27           DEL → BOM → COK    07:00         12:55   5h 55m      1 stop
# 28                 BLR → DEL    09:45         12:35   2h 50m    non-stop
# 29                 MAA → CCU    07:05         09:20   2h 15m    non-stop
# ...                      ...      ...           ...      ...         ...
# 10652        CCU → BOM → BLR    14:05  12:00 02 May  21h 55m      1 stop
# 10653              BLR → DEL    05:55         08:35   2h 40m    non-stop
# 10654              BOM → HYD    02:55         04:20   1h 25m    non-stop
# 10655              BLR → DEL    07:00         09:40   2h 40m    non-stop
# 10656        CCU → BOM → BLR    20:00  09:20 07 May  13h 20m      1 stop
# 10657              BLR → DEL    11:10         14:05   2h 55m    non-stop
# 10658              BLR → DEL    21:00         23:50   2h 50m    non-stop
# 10659              BLR → DEL    21:10  00:05 19 Mar   2h 55m    non-stop
# 10660        DEL → BOM → COK    13:00         19:15   6h 15m      1 stop
# 10661  CCU → BOM → GOI → BLR    09:25  05:35 25 Mar  20h 10m     2 stops
# 10662  DEL → JAI → BOM → COK    19:30  12:35 07 Jun   17h 5m     2 stops
# 10663              BLR → DEL    18:55         21:50   2h 55m    non-stop
# 10664              CCU → BLR    15:15         17:45   2h 30m    non-stop
# 10665        DEL → BOM → COK    18:15  19:00 13 Jun  24h 45m      1 stop
# 10666        BLR → BOM → DEL    22:55  20:20 13 Mar  21h 25m      1 stop
# 10667  DEL → JDH → BOM → COK    11:40         19:00   7h 20m     2 stops
# 10668        DEL → BOM → COK    08:00         19:15  11h 15m      1 stop
# 10669  CCU → IXR → DEL → BLR    05:50         23:15  17h 25m     2 stops
# 10670              BOM → HYD    21:05         22:25   1h 20m    non-stop
# 10671  DEL → AMD → BOM → COK    23:05  19:00 28 Jun  19h 55m     2 stops
# 10672  DEL → AMD → BOM → COK    13:25  04:25 28 May      15h     2 stops
# 10673        BLR → BOM → DEL    20:35  21:20 13 Mar  24h 45m      1 stop
# 10674              BOM → HYD    06:20         07:40   1h 20m    non-stop
# 10675        DEL → BOM → COK    10:20         19:00   8h 40m      1 stop
# 10676              BLR → DEL    05:55         08:35   2h 40m    non-stop
# 10677              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10678              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10679              BLR → DEL    08:20         11:20       3h    non-stop
# 10680              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10681  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#                     Additional_Info  Price
# 0                           No info   3897
# 1                           No info   7662
# 2                           No info  13882
# 3                           No info   6218
# 4                           No info  13302
# 5                           No info   3873
# 6       In-flight meal not included  11087
# 7                           No info  22270
# 8       In-flight meal not included  11087
# 9                           No info   8625
# 10                          No info   8907
# 11                          No info   4174
# 12                          No info   4667
# 13      In-flight meal not included   9663
# 14                          No info   4804
# 15                          No info  14011
# 16                          No info   5830
# 17      In-flight meal not included  10262
# 18                          No info  13381
# 19      In-flight meal not included  12898
# 20                          No info  19495
# 21                          No info   6955
# 22                          No info   3943
# 23                          No info   4823
# 24      In-flight meal not included   7757
# 25                          No info  13292
# 26                          No info   8238
# 27                          No info   7682
# 28                          No info   4668
# 29                          No info   3687
# ...                             ...    ...
# 10652                       No info  14388
# 10653  No check-in baggage included   4319
# 10654                       No info   5678
# 10655                       No info   5613
# 10656   In-flight meal not included   9663
# 10657   In-flight meal not included   5769
# 10658                       No info   4668
# 10659                       No info   4878
# 10660                       No info   8372
# 10661                       No info  12352
# 10662   In-flight meal not included  11733
# 10663                       No info   4823
# 10664                       No info   4804
# 10665   In-flight meal not included  10262
# 10666   In-flight meal not included  11087
# 10667                       No info  21219
# 10668                       No info   9929
# 10669                       No info  11411
# 10670                       No info   3100
# 10671   In-flight meal not included  11150
# 10672                       No info  16704
# 10673   In-flight meal not included  11087
# 10674                       No info   3100
# 10675                       No info   9794
# 10676  No check-in baggage included   3257
# 10677                       No info   4107
# 10678                       No info   4145
# 10679                       No info   7229
# 10680                       No info  12648
# 10681                       No info  11753
#
# [10682 rows x 11 columns]

# %%
df[df.duplicated()]
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 683    Jet Airways       1/06/2019     Delhi      Cochin
# 1061     Air India      21/05/2019     Delhi      Cochin
# 1348     Air India      18/05/2019     Delhi      Cochin
# 1418   Jet Airways       6/06/2019     Delhi      Cochin
# 1674        IndiGo      24/03/2019  Banglore   New Delhi
# 1685   Jet Airways       9/05/2019     Delhi      Cochin
# 1704        IndiGo      09/03/2019  Banglore   New Delhi
# 1807   Jet Airways       1/06/2019     Delhi      Cochin
# 1891   Jet Airways       1/06/2019     Delhi      Cochin
# 1971   Jet Airways       9/05/2019     Delhi      Cochin
# 1982     Air India       1/06/2019     Delhi      Cochin
# 2093   Jet Airways       9/06/2019     Delhi      Cochin
# 2548   Jet Airways       9/05/2019     Delhi      Cochin
# 2595     Air India      15/06/2019     Delhi      Cochin
# 2661   Jet Airways      21/05/2019     Delhi      Cochin
# 2677   Jet Airways       9/06/2019     Delhi      Cochin
# 2716     Air India       9/05/2019     Delhi      Cochin
# 2845   Jet Airways       6/06/2019     Delhi      Cochin
# 2870      SpiceJet      24/03/2019  Banglore   New Delhi
# 2903   Jet Airways      18/05/2019     Delhi      Cochin
# 2943   Jet Airways       9/05/2019     Delhi      Cochin
# 3003     Air India       9/05/2019     Delhi      Cochin
# 3102   Jet Airways      24/06/2019     Delhi      Cochin
# 3135        IndiGo      03/03/2019  Banglore   New Delhi
# 3151   Jet Airways      18/05/2019     Delhi      Cochin
# 3256     Air India      21/05/2019   Kolkata    Banglore
# 3283   Jet Airways      15/06/2019     Delhi      Cochin
# 3363   Jet Airways      21/03/2019     Delhi      Cochin
# 3450   Jet Airways       9/05/2019     Delhi      Cochin
# 3457     Air India       6/03/2019     Delhi      Cochin
# ...            ...             ...       ...         ...
# 10112  Jet Airways      18/05/2019     Delhi      Cochin
# 10115       IndiGo      09/03/2019  Banglore   New Delhi
# 10146    Air India      21/05/2019     Delhi      Cochin
# 10183    Air India       1/05/2019   Kolkata    Banglore
# 10193  Jet Airways      15/06/2019     Delhi      Cochin
# 10207  Jet Airways       3/06/2019     Delhi      Cochin
# 10227    Air India      21/05/2019   Kolkata    Banglore
# 10242  Jet Airways      27/05/2019     Delhi      Cochin
# 10259  Jet Airways       1/06/2019     Delhi      Cochin
# 10265    Air India      12/06/2019     Delhi      Cochin
# 10266  Jet Airways       3/06/2019     Delhi      Cochin
# 10275       IndiGo      03/03/2019  Banglore   New Delhi
# 10291  Jet Airways      27/06/2019     Delhi      Cochin
# 10298  Jet Airways      18/05/2019     Delhi      Cochin
# 10396  Jet Airways       6/06/2019     Delhi      Cochin
# 10406    Air India       6/03/2019     Delhi      Cochin
# 10420    Air India      27/03/2019     Delhi      Cochin
# 10453  Jet Airways      24/06/2019     Delhi      Cochin
# 10474  Jet Airways      15/06/2019     Delhi      Cochin
# 10526  Jet Airways       6/06/2019     Delhi      Cochin
# 10533  Jet Airways      24/03/2019  Banglore   New Delhi
# 10547  Jet Airways      12/06/2019     Delhi      Cochin
# 10554  Jet Airways       6/06/2019     Delhi      Cochin
# 10573    Air India      27/06/2019     Delhi      Cochin
# 10589  Jet Airways      12/06/2019     Delhi      Cochin
# 10594  Jet Airways      27/06/2019     Delhi      Cochin
# 10616  Jet Airways       1/06/2019     Delhi      Cochin
# 10634  Jet Airways       6/06/2019     Delhi      Cochin
# 10672  Jet Airways      27/06/2019     Delhi      Cochin
# 10673  Jet Airways      27/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 683    DEL → NAG → BOM → COK    14:35  04:25 02 Jun  13h 50m     2 stops
# 1061   DEL → GOI → BOM → COK    22:00  19:15 22 May  21h 15m     2 stops
# 1348   DEL → HYD → BOM → COK    17:15  19:15 19 May      26h     2 stops
# 1418   DEL → JAI → BOM → COK    05:30  04:25 07 Jun  22h 55m     2 stops
# 1674               BLR → DEL    18:25         21:20   2h 55m    non-stop
# 1685   DEL → AMD → BOM → COK    23:05  12:35 10 May  13h 30m     2 stops
# 1704               BLR → DEL    18:25         21:20   2h 55m    non-stop
# 1807   DEL → NAG → BOM → COK    06:45  04:25 02 Jun  21h 40m     2 stops
# 1891   DEL → JAI → BOM → COK    09:40  12:35 02 Jun  26h 55m     2 stops
# 1971   DEL → AMD → BOM → COK    23:05  04:25 11 May  29h 20m     2 stops
# 1982   DEL → AMD → BOM → COK    19:45  19:15 02 Jun  23h 30m     2 stops
# 2093   DEL → JAI → BOM → COK    05:30  04:25 10 Jun  22h 55m     2 stops
# 2548   DEL → AMD → BOM → COK    23:05  04:25 11 May  29h 20m     2 stops
# 2595   DEL → AMD → BOM → COK    19:45  19:15 16 Jun  23h 30m     2 stops
# 2661   DEL → AMD → BOM → COK    19:10  19:00 22 May  23h 50m     2 stops
# 2677   DEL → JAI → BOM → COK    05:30  04:25 10 Jun  22h 55m     2 stops
# 2716   DEL → GOI → BOM → COK    22:00  19:15 10 May  21h 15m     2 stops
# 2845   DEL → JAI → BOM → COK    05:30  04:25 07 Jun  22h 55m     2 stops
# 2870               BLR → DEL    05:45         08:35   2h 50m    non-stop
# 2903   DEL → AMD → BOM → COK    23:05  04:25 20 May  29h 20m     2 stops
# 2943   DEL → JAI → BOM → COK    09:40  12:35 10 May  26h 55m     2 stops
# 3003   DEL → GOI → BOM → COK    22:00  19:15 10 May  21h 15m     2 stops
# 3102   DEL → AMD → BOM → COK    23:05  12:35 25 Jun  13h 30m     2 stops
# 3135               BLR → DEL    10:05         13:00   2h 55m    non-stop
# 3151   DEL → JAI → BOM → COK    05:30  04:25 19 May  22h 55m     2 stops
# 3256   CCU → DEL → COK → BLR    10:00  01:20 22 May  15h 20m     2 stops
# 3283   DEL → NAG → BOM → COK    06:45  04:25 16 Jun  21h 40m     2 stops
# 3363   DEL → MAA → BOM → COK    13:55  18:50 22 Mar  28h 55m     2 stops
# 3450   DEL → JAI → BOM → COK    05:30  04:25 10 May  22h 55m     2 stops
# 3457   DEL → HYD → BOM → COK    07:05  19:15 07 Mar  36h 10m     2 stops
# ...                      ...      ...           ...      ...         ...
# 10112  DEL → JAI → BOM → COK    05:30  04:25 19 May  22h 55m     2 stops
# 10115              BLR → DEL    10:05         13:00   2h 55m    non-stop
# 10146  DEL → HYD → BOM → COK    17:15  19:15 22 May      26h     2 stops
# 10183  CCU → GAU → DEL → BLR    09:50  08:55 02 May   23h 5m     2 stops
# 10193  DEL → NAG → BOM → COK    14:35  12:35 16 Jun      22h     2 stops
# 10207  DEL → NAG → BOM → COK    14:35  12:35 04 Jun      22h     2 stops
# 10227  CCU → BOM → GOI → BLR    16:50  05:35 22 May  12h 45m     2 stops
# 10242  DEL → AMD → BOM → COK    19:10  12:35 28 May  17h 25m     2 stops
# 10259  DEL → NAG → BOM → COK    06:45  04:25 02 Jun  21h 40m     2 stops
# 10265  DEL → GOI → BOM → COK    22:00  19:15 13 Jun  21h 15m     2 stops
# 10266  DEL → JAI → BOM → COK    09:40  12:35 04 Jun  26h 55m     2 stops
# 10275              BLR → DEL    08:30         11:30       3h    non-stop
# 10291  DEL → AMD → BOM → COK    13:25  12:35 28 Jun  23h 10m     2 stops
# 10298  DEL → JAI → BOM → COK    05:30         19:00  13h 30m     2 stops
# 10396  DEL → JAI → BOM → COK    09:40  04:25 07 Jun  18h 45m     2 stops
# 10406  DEL → AMD → BOM → COK    16:40  19:15 07 Mar  26h 35m     2 stops
# 10420  DEL → AMD → BOM → COK    16:40  19:15 28 Mar  26h 35m     2 stops
# 10453  DEL → JAI → BOM → COK    09:40  12:35 25 Jun  26h 55m     2 stops
# 10474  DEL → NAG → BOM → COK    14:35  04:25 16 Jun  13h 50m     2 stops
# 10526  DEL → JAI → BOM → COK    09:40  04:25 07 Jun  18h 45m     2 stops
# 10533              BLR → DEL    19:55         22:35   2h 40m    non-stop
# 10547  DEL → JAI → BOM → COK    05:30         19:00  13h 30m     2 stops
# 10554  DEL → JAI → BOM → COK    05:30         19:00  13h 30m     2 stops
# 10573  DEL → AMD → BOM → COK    16:40  19:15 28 Jun  26h 35m     2 stops
# 10589  DEL → IDR → BOM → COK    05:30  04:25 13 Jun  22h 55m     2 stops
# 10594  DEL → AMD → BOM → COK    23:05  12:35 28 Jun  13h 30m     2 stops
# 10616  DEL → JAI → BOM → COK    09:40  12:35 02 Jun  26h 55m     2 stops
# 10634  DEL → JAI → BOM → COK    09:40  12:35 07 Jun  26h 55m     2 stops
# 10672  DEL → AMD → BOM → COK    23:05  19:00 28 Jun  19h 55m     2 stops
# 10673  DEL → AMD → BOM → COK    13:25  04:25 28 May      15h     2 stops
#
#                     Additional_Info  Price
# 683                         No info  13376
# 1061                        No info  10231
# 1348                        No info  12392
# 1418    In-flight meal not included  10368
# 1674                        No info   7303
# 1685                        No info  15129
# 1704                        No info   6860
# 1807    In-flight meal not included  10919
# 1891    In-flight meal not included  10368
# 1971                        No info  15129
# 1982                        No info  10651
# 2093    In-flight meal not included  10368
# 2548                        No info  16704
# 2595                        No info   9653
# 2661                        No info  15129
# 2677                        No info  13014
# 2716                        No info  10441
# 2845    In-flight meal not included  10368
# 2870   No check-in baggage included   4273
# 2903                        No info  16704
# 2943                        No info  15129
# 3003                        No info  10441
# 3102                        No info  12819
# 3135                        No info   7648
# 3151    In-flight meal not included  13029
# 3256                        No info  13033
# 3283    In-flight meal not included  10919
# 3363    In-flight meal not included   8728
# 3450    In-flight meal not included  13029
# 3457                        No info  11552
# ...                             ...    ...
# 10112                       No info  15129
# 10115                       No info   6860
# 10146                       No info  11972
# 10183                       No info  13227
# 10193                       No info  13376
# 10207   In-flight meal not included  10919
# 10227                       No info  12324
# 10242                       No info  15129
# 10259                       No info  13376
# 10265                       No info  10231
# 10266   In-flight meal not included  10368
# 10275                       No info   6860
# 10291   In-flight meal not included  11150
# 10298   In-flight meal not included  13029
# 10396                       No info  13014
# 10406                       No info  12646
# 10420                       No info   8656
# 10453                       No info  13014
# 10474                       No info  13376
# 10526   In-flight meal not included  10368
# 10533                       No info   7229
# 10547   In-flight meal not included  10368
# 10554   In-flight meal not included  10368
# 10573                       No info   9653
# 10589                       No info  13292
# 10594                       No info  12819
# 10616                       No info  13014
# 10634   In-flight meal not included  11733
# 10672   In-flight meal not included  11150
# 10673                       No info  16704
#
# [220 rows x 11 columns]

# %%
df.drop_duplicates(keep ='first', inplace=True)
df.reset_index(drop=True)
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 0                 IndiGo      24/03/2019  Banglore   New Delhi
# 1              Air India       1/05/2019   Kolkata    Banglore
# 2            Jet Airways       9/06/2019     Delhi      Cochin
# 3                 IndiGo      12/05/2019   Kolkata    Banglore
# 4                 IndiGo      01/03/2019  Banglore   New Delhi
# 5               SpiceJet      24/06/2019   Kolkata    Banglore
# 6            Jet Airways      12/03/2019  Banglore   New Delhi
# 7            Jet Airways      01/03/2019  Banglore   New Delhi
# 8            Jet Airways      12/03/2019  Banglore   New Delhi
# 9      Multiple carriers      27/05/2019     Delhi      Cochin
# 10             Air India       1/06/2019     Delhi      Cochin
# 11                IndiGo      18/04/2019   Kolkata    Banglore
# 12             Air India      24/06/2019   Chennai     Kolkata
# 13           Jet Airways       9/05/2019   Kolkata    Banglore
# 14                IndiGo      24/04/2019   Kolkata    Banglore
# 15             Air India       3/03/2019     Delhi      Cochin
# 16              SpiceJet      15/04/2019     Delhi      Cochin
# 17           Jet Airways      12/06/2019     Delhi      Cochin
# 18             Air India      12/06/2019     Delhi      Cochin
# 19           Jet Airways      27/05/2019     Delhi      Cochin
# 20                 GoAir       6/03/2019     Delhi      Cochin
# 21             Air India      21/03/2019  Banglore   New Delhi
# 22                IndiGo       3/04/2019  Banglore       Delhi
# 23                IndiGo       1/05/2019  Banglore       Delhi
# 24           Jet Airways       6/05/2019   Kolkata    Banglore
# 25           Jet Airways       9/06/2019     Delhi      Cochin
# 26                IndiGo       1/06/2019     Delhi      Cochin
# 27                 GoAir      15/05/2019     Delhi      Cochin
# 28               Vistara      18/06/2019  Banglore       Delhi
# 29               Vistara      15/06/2019   Chennai     Kolkata
# ...                  ...             ...       ...         ...
# 10432  Multiple carriers      27/06/2019     Delhi      Cochin
# 10433          Air India       9/03/2019     Delhi      Cochin
# 10434        Jet Airways       1/05/2019   Kolkata    Banglore
# 10435           SpiceJet      12/06/2019  Banglore       Delhi
# 10436        Jet Airways       3/05/2019    Mumbai   Hyderabad
# 10437            Vistara       6/04/2019  Banglore       Delhi
# 10438        Jet Airways       6/05/2019   Kolkata    Banglore
# 10439        Jet Airways      18/06/2019  Banglore       Delhi
# 10440            Vistara       1/05/2019  Banglore       Delhi
# 10441            Vistara      21/03/2019  Banglore   New Delhi
# 10442          Air India       9/05/2019     Delhi      Cochin
# 10443          Air India      24/03/2019   Kolkata    Banglore
# 10444        Jet Airways       6/06/2019     Delhi      Cochin
# 10445             IndiGo       9/04/2019  Banglore       Delhi
# 10446             IndiGo      27/04/2019   Kolkata    Banglore
# 10447        Jet Airways      12/06/2019     Delhi      Cochin
# 10448        Jet Airways      12/03/2019  Banglore   New Delhi
# 10449        Jet Airways       9/05/2019     Delhi      Cochin
# 10450          Air India      15/06/2019     Delhi      Cochin
# 10451          Air India      12/05/2019   Kolkata    Banglore
# 10452          Air India       6/06/2019    Mumbai   Hyderabad
# 10453        Jet Airways      12/03/2019  Banglore   New Delhi
# 10454          Air India       9/06/2019    Mumbai   Hyderabad
# 10455  Multiple carriers       1/05/2019     Delhi      Cochin
# 10456           SpiceJet      21/05/2019  Banglore       Delhi
# 10457           Air Asia       9/04/2019   Kolkata    Banglore
# 10458          Air India      27/04/2019   Kolkata    Banglore
# 10459        Jet Airways      27/04/2019  Banglore       Delhi
# 10460            Vistara      01/03/2019  Banglore   New Delhi
# 10461          Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# 5                  CCU → BLR    09:00         11:25   2h 25m    non-stop
# 6            BLR → BOM → DEL    18:55  10:25 13 Mar  15h 30m      1 stop
# 7            BLR → BOM → DEL    08:00  05:05 02 Mar   21h 5m      1 stop
# 8            BLR → BOM → DEL    08:55  10:25 13 Mar  25h 30m      1 stop
# 9            DEL → BOM → COK    11:25         19:15   7h 50m      1 stop
# 10           DEL → BLR → COK    09:45         23:00  13h 15m      1 stop
# 11                 CCU → BLR    20:20         22:55   2h 35m    non-stop
# 12                 MAA → CCU    11:40         13:55   2h 15m    non-stop
# 13           CCU → BOM → BLR    21:10  09:20 10 May  12h 10m      1 stop
# 14                 CCU → BLR    17:15         19:50   2h 35m    non-stop
# 15     DEL → AMD → BOM → COK    16:40  19:15 04 Mar  26h 35m     2 stops
# 16           DEL → PNQ → COK    08:45         13:15   4h 30m      1 stop
# 17           DEL → BOM → COK    14:00  12:35 13 Jun  22h 35m      1 stop
# 18     DEL → CCU → BOM → COK    20:15  19:15 13 Jun      23h     2 stops
# 19           DEL → BOM → COK    16:00  12:35 28 May  20h 35m      1 stop
# 20           DEL → BOM → COK    14:10         19:20   5h 10m      1 stop
# 21           BLR → COK → DEL    22:00  13:20 19 Mar  15h 20m      1 stop
# 22                 BLR → DEL    04:00         06:50   2h 50m    non-stop
# 23                 BLR → DEL    18:55         21:50   2h 55m    non-stop
# 24           CCU → BOM → BLR    18:55  08:15 07 May  13h 20m      1 stop
# 25     DEL → IDR → BOM → COK    21:25  12:35 10 Jun  15h 10m     2 stops
# 26           DEL → LKO → COK    21:50  03:35 02 Jun   5h 45m      1 stop
# 27           DEL → BOM → COK    07:00         12:55   5h 55m      1 stop
# 28                 BLR → DEL    09:45         12:35   2h 50m    non-stop
# 29                 MAA → CCU    07:05         09:20   2h 15m    non-stop
# ...                      ...      ...           ...      ...         ...
# 10432        DEL → BOM → COK    04:55         12:35   7h 40m      1 stop
# 10433        DEL → TRV → COK    05:15  06:50 10 Mar  25h 35m      1 stop
# 10434        CCU → BOM → BLR    14:05  12:00 02 May  21h 55m      1 stop
# 10435              BLR → DEL    05:55         08:35   2h 40m    non-stop
# 10436              BOM → HYD    02:55         04:20   1h 25m    non-stop
# 10437              BLR → DEL    07:00         09:40   2h 40m    non-stop
# 10438        CCU → BOM → BLR    20:00  09:20 07 May  13h 20m      1 stop
# 10439              BLR → DEL    11:10         14:05   2h 55m    non-stop
# 10440              BLR → DEL    21:00         23:50   2h 50m    non-stop
# 10441              BLR → DEL    21:10  00:05 19 Mar   2h 55m    non-stop
# 10442        DEL → BOM → COK    13:00         19:15   6h 15m      1 stop
# 10443  CCU → BOM → GOI → BLR    09:25  05:35 25 Mar  20h 10m     2 stops
# 10444  DEL → JAI → BOM → COK    19:30  12:35 07 Jun   17h 5m     2 stops
# 10445              BLR → DEL    18:55         21:50   2h 55m    non-stop
# 10446              CCU → BLR    15:15         17:45   2h 30m    non-stop
# 10447        DEL → BOM → COK    18:15  19:00 13 Jun  24h 45m      1 stop
# 10448        BLR → BOM → DEL    22:55  20:20 13 Mar  21h 25m      1 stop
# 10449  DEL → JDH → BOM → COK    11:40         19:00   7h 20m     2 stops
# 10450        DEL → BOM → COK    08:00         19:15  11h 15m      1 stop
# 10451  CCU → IXR → DEL → BLR    05:50         23:15  17h 25m     2 stops
# 10452              BOM → HYD    21:05         22:25   1h 20m    non-stop
# 10453        BLR → BOM → DEL    20:35  21:20 13 Mar  24h 45m      1 stop
# 10454              BOM → HYD    06:20         07:40   1h 20m    non-stop
# 10455        DEL → BOM → COK    10:20         19:00   8h 40m      1 stop
# 10456              BLR → DEL    05:55         08:35   2h 40m    non-stop
# 10457              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10458              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10459              BLR → DEL    08:20         11:20       3h    non-stop
# 10460              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10461  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#                     Additional_Info  Price
# 0                           No info   3897
# 1                           No info   7662
# 2                           No info  13882
# 3                           No info   6218
# 4                           No info  13302
# 5                           No info   3873
# 6       In-flight meal not included  11087
# 7                           No info  22270
# 8       In-flight meal not included  11087
# 9                           No info   8625
# 10                          No info   8907
# 11                          No info   4174
# 12                          No info   4667
# 13      In-flight meal not included   9663
# 14                          No info   4804
# 15                          No info  14011
# 16                          No info   5830
# 17      In-flight meal not included  10262
# 18                          No info  13381
# 19      In-flight meal not included  12898
# 20                          No info  19495
# 21                          No info   6955
# 22                          No info   3943
# 23                          No info   4823
# 24      In-flight meal not included   7757
# 25                          No info  13292
# 26                          No info   8238
# 27                          No info   7682
# 28                          No info   4668
# 29                          No info   3687
# ...                             ...    ...
# 10432                       No info  10678
# 10433                       No info   9790
# 10434                       No info  14388
# 10435  No check-in baggage included   4319
# 10436                       No info   5678
# 10437                       No info   5613
# 10438   In-flight meal not included   9663
# 10439   In-flight meal not included   5769
# 10440                       No info   4668
# 10441                       No info   4878
# 10442                       No info   8372
# 10443                       No info  12352
# 10444   In-flight meal not included  11733
# 10445                       No info   4823
# 10446                       No info   4804
# 10447   In-flight meal not included  10262
# 10448   In-flight meal not included  11087
# 10449                       No info  21219
# 10450                       No info   9929
# 10451                       No info  11411
# 10452                       No info   3100
# 10453   In-flight meal not included  11087
# 10454                       No info   3100
# 10455                       No info   9794
# 10456  No check-in baggage included   3257
# 10457                       No info   4107
# 10458                       No info   4145
# 10459                       No info   7229
# 10460                       No info  12648
# 10461                       No info  11753
#
# [10462 rows x 11 columns]

# %%
detail_info(df)
# Out:
#                 data_type  unique_val  duplicate_val  missing_val  \
# Airline            object          12              0            0
# Date_of_Journey    object          44              0            0
# Source             object           5              0            0
# Destination        object           6              0            0
# Route              object         128              0            0
# Dep_Time           object         222              0            0
# Arrival_Time       object        1343              0            0
# Duration           object         368              0            0
# Total_Stops        object           5              0            0
# Additional_Info    object          10              0            0
# Price               int64        1870              0            0
#
#                  missing_val_%
# Airline                    0.0
# Date_of_Journey            0.0
# Source                     0.0
# Destination                0.0
# Route                      0.0
# Dep_Time                   0.0
# Arrival_Time               0.0
# Duration                   0.0
# Total_Stops                0.0
# Additional_Info            0.0
# Price                      0.0

# %%
df.shape
# Out:
# (10462, 11)

# %%
def split_date(data, col):
    data['date'] = data[col].str.split('/').str[0]
    data['month']= data[col].str.split('/').str[1]
    data['year'] = data[col].str.split('/').str[2]
    
    data['date'] = data['date'].astype(int)
    data['month']= data['month'].astype(int)
    data['year'] = data['year'].astype(int)
    data.drop(col, axis =1, inplace=True)

# %%
split_date(df,'Date_of_Journey')

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  date  month  year
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897    24      3  2019
# 1         13:15   7h 25m     2 stops         No info   7662     1      5  2019
# 2  04:25 10 Jun      19h     2 stops         No info  13882     9      6  2019
# 3         23:30   5h 25m      1 stop         No info   6218    12      5  2019
# 4         21:35   4h 45m      1 stop         No info  13302     1      3  2019

# %%
def extract_hours(data, col):
    data[col] =data[col].str.split(' ').str[0]
    
    data[col+'_hour'] = data[col].str.split(':').str[0]
    data[col+'_min']  = data[col].str.split(':').str[1]
    data[col+'_hour'] = data[col+'_hour'].astype(int)
    data[col+'_min']  = data[col+'_min'].astype(int)    
    
    data.drop(col, axis =1, inplace=True)

# %%
extract_hours(df, 'Dep_Time')
extract_hours(df, 'Arrival_Time')

# %%
df.head(3)
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
#
#   Total_Stops Additional_Info  Price  date  month  year  Dep_Time_hour  \
# 0    non-stop         No info   3897    24      3  2019             22
# 1     2 stops         No info   7662     1      5  2019              5
# 2     2 stops         No info  13882     9      6  2019              9
#
#    Dep_Time_min  Arrival_Time_hour  Arrival_Time_min
# 0            20                  1                10
# 1            50                 13                15
# 2            25                  4                25

# %%
def convert_duration(data, col):
    duration = list(data[col])
    for i in range(len(duration)):
        if len(duration[i].split(' '))==2:
            pass
        else:
            if 'h' in duration[i]:                  # Check if duration contains only hours
                duration[i] = duration[i] + ' 0m'  # Adds 0 minutes
            else:
                duration[i] ='0h '+ duration[i]    # Adds 0 hours, if only minutes available
    data[col] = duration

# %%
convert_duration(df, 'Duration')

# %%
df.head(3)
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK   19h 0m
#
#   Total_Stops Additional_Info  Price  date  month  year  Dep_Time_hour  \
# 0    non-stop         No info   3897    24      3  2019             22
# 1     2 stops         No info   7662     1      5  2019              5
# 2     2 stops         No info  13882     9      6  2019              9
#
#    Dep_Time_min  Arrival_Time_hour  Arrival_Time_min
# 0            20                  1                10
# 1            50                 13                15
# 2            25                  4                25

# %%
def extract_duration(data, col):
    data[col+'_hour'] = data[col].str.split(' ').str[0].str.replace('h','')
    data[col+'_min']  = data[col].str.split(' ').str[1].str.replace('m','')
    data[col+'_hour'] = data[col+'_hour'].astype(int)
    data[col+'_min']  = data[col+'_min'].astype(int)    
    
    data.drop(col, axis =1, inplace=True)

# %%
extract_duration(df, 'Duration')

# %%
df.head(3)
# Out:
#        Airline    Source Destination                  Route Total_Stops  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    non-stop
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
#
#   Additional_Info  Price  date  month  year  Dep_Time_hour  Dep_Time_min  \
# 0         No info   3897    24      3  2019             22            20
# 1         No info   7662     1      5  2019              5            50
# 2         No info  13882     9      6  2019              9            25
#
#    Arrival_Time_hour  Arrival_Time_min  Duration_hour  Duration_min
# 0                  1                10              2            50
# 1                 13                15              7            25
# 2                  4                25             19             0

# %%
# Lets find how many flights took duration only in minutes 

df[df['Duration_hour']==0]
# Out:
#         Airline  Source Destination                  Route Total_Stops  \
# 6474  Air India  Mumbai   Hyderabad  BOM → GOI → PNQ → HYD     2 stops
#
#      Additional_Info  Price  date  month  year  Dep_Time_hour  Dep_Time_min  \
# 6474         No info  17327     6      3  2019             16            50
#
#       Arrival_Time_hour  Arrival_Time_min  Duration_hour  Duration_min
# 6474                 16                55              0             5

# %%
# It is not poassible that the flight took only 5 min to travel between Mumbai to Hyderbad

df.drop(6474, axis=0, inplace=True)
df.reset_index(drop=True)
# Out:
#                  Airline    Source Destination                  Route  \
# 0                 IndiGo  Banglore   New Delhi              BLR → DEL
# 1              Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2            Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK
# 3                 IndiGo   Kolkata    Banglore        CCU → NAG → BLR
# 4                 IndiGo  Banglore   New Delhi        BLR → NAG → DEL
# 5               SpiceJet   Kolkata    Banglore              CCU → BLR
# 6            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 7            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 8            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 9      Multiple carriers     Delhi      Cochin        DEL → BOM → COK
# 10             Air India     Delhi      Cochin        DEL → BLR → COK
# 11                IndiGo   Kolkata    Banglore              CCU → BLR
# 12             Air India   Chennai     Kolkata              MAA → CCU
# 13           Jet Airways   Kolkata    Banglore        CCU → BOM → BLR
# 14                IndiGo   Kolkata    Banglore              CCU → BLR
# 15             Air India     Delhi      Cochin  DEL → AMD → BOM → COK
# 16              SpiceJet     Delhi      Cochin        DEL → PNQ → COK
# 17           Jet Airways     Delhi      Cochin        DEL → BOM → COK
# 18             Air India     Delhi      Cochin  DEL → CCU → BOM → COK
# 19           Jet Airways     Delhi      Cochin        DEL → BOM → COK
# 20                 GoAir     Delhi      Cochin        DEL → BOM → COK
# 21             Air India  Banglore   New Delhi        BLR → COK → DEL
# 22                IndiGo  Banglore       Delhi              BLR → DEL
# 23                IndiGo  Banglore       Delhi              BLR → DEL
# 24           Jet Airways   Kolkata    Banglore        CCU → BOM → BLR
# 25           Jet Airways     Delhi      Cochin  DEL → IDR → BOM → COK
# 26                IndiGo     Delhi      Cochin        DEL → LKO → COK
# 27                 GoAir     Delhi      Cochin        DEL → BOM → COK
# 28               Vistara  Banglore       Delhi              BLR → DEL
# 29               Vistara   Chennai     Kolkata              MAA → CCU
# ...                  ...       ...         ...                    ...
# 10431  Multiple carriers     Delhi      Cochin        DEL → BOM → COK
# 10432          Air India     Delhi      Cochin        DEL → TRV → COK
# 10433        Jet Airways   Kolkata    Banglore        CCU → BOM → BLR
# 10434           SpiceJet  Banglore       Delhi              BLR → DEL
# 10435        Jet Airways    Mumbai   Hyderabad              BOM → HYD
# 10436            Vistara  Banglore       Delhi              BLR → DEL
# 10437        Jet Airways   Kolkata    Banglore        CCU → BOM → BLR
# 10438        Jet Airways  Banglore       Delhi              BLR → DEL
# 10439            Vistara  Banglore       Delhi              BLR → DEL
# 10440            Vistara  Banglore   New Delhi              BLR → DEL
# 10441          Air India     Delhi      Cochin        DEL → BOM → COK
# 10442          Air India   Kolkata    Banglore  CCU → BOM → GOI → BLR
# 10443        Jet Airways     Delhi      Cochin  DEL → JAI → BOM → COK
# 10444             IndiGo  Banglore       Delhi              BLR → DEL
# 10445             IndiGo   Kolkata    Banglore              CCU → BLR
# 10446        Jet Airways     Delhi      Cochin        DEL → BOM → COK
# 10447        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 10448        Jet Airways     Delhi      Cochin  DEL → JDH → BOM → COK
# 10449          Air India     Delhi      Cochin        DEL → BOM → COK
# 10450          Air India   Kolkata    Banglore  CCU → IXR → DEL → BLR
# 10451          Air India    Mumbai   Hyderabad              BOM → HYD
# 10452        Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 10453          Air India    Mumbai   Hyderabad              BOM → HYD
# 10454  Multiple carriers     Delhi      Cochin        DEL → BOM → COK
# 10455           SpiceJet  Banglore       Delhi              BLR → DEL
# 10456           Air Asia   Kolkata    Banglore              CCU → BLR
# 10457          Air India   Kolkata    Banglore              CCU → BLR
# 10458        Jet Airways  Banglore       Delhi              BLR → DEL
# 10459            Vistara  Banglore   New Delhi              BLR → DEL
# 10460          Air India     Delhi      Cochin  DEL → GOI → BOM → COK
#
#       Total_Stops               Additional_Info  Price  date  month  year  \
# 0        non-stop                       No info   3897    24      3  2019
# 1         2 stops                       No info   7662     1      5  2019
# 2         2 stops                       No info  13882     9      6  2019
# 3          1 stop                       No info   6218    12      5  2019
# 4          1 stop                       No info  13302     1      3  2019
# 5        non-stop                       No info   3873    24      6  2019
# 6          1 stop   In-flight meal not included  11087    12      3  2019
# 7          1 stop                       No info  22270     1      3  2019
# 8          1 stop   In-flight meal not included  11087    12      3  2019
# 9          1 stop                       No info   8625    27      5  2019
# 10         1 stop                       No info   8907     1      6  2019
# 11       non-stop                       No info   4174    18      4  2019
# 12       non-stop                       No info   4667    24      6  2019
# 13         1 stop   In-flight meal not included   9663     9      5  2019
# 14       non-stop                       No info   4804    24      4  2019
# 15        2 stops                       No info  14011     3      3  2019
# 16         1 stop                       No info   5830    15      4  2019
# 17         1 stop   In-flight meal not included  10262    12      6  2019
# 18        2 stops                       No info  13381    12      6  2019
# 19         1 stop   In-flight meal not included  12898    27      5  2019
# 20         1 stop                       No info  19495     6      3  2019
# 21         1 stop                       No info   6955    21      3  2019
# 22       non-stop                       No info   3943     3      4  2019
# 23       non-stop                       No info   4823     1      5  2019
# 24         1 stop   In-flight meal not included   7757     6      5  2019
# 25        2 stops                       No info  13292     9      6  2019
# 26         1 stop                       No info   8238     1      6  2019
# 27         1 stop                       No info   7682    15      5  2019
# 28       non-stop                       No info   4668    18      6  2019
# 29       non-stop                       No info   3687    15      6  2019
# ...           ...                           ...    ...   ...    ...   ...
# 10431      1 stop                       No info  10678    27      6  2019
# 10432      1 stop                       No info   9790     9      3  2019
# 10433      1 stop                       No info  14388     1      5  2019
# 10434    non-stop  No check-in baggage included   4319    12      6  2019
# 10435    non-stop                       No info   5678     3      5  2019
# 10436    non-stop                       No info   5613     6      4  2019
# 10437      1 stop   In-flight meal not included   9663     6      5  2019
# 10438    non-stop   In-flight meal not included   5769    18      6  2019
# 10439    non-stop                       No info   4668     1      5  2019
# 10440    non-stop                       No info   4878    21      3  2019
# 10441      1 stop                       No info   8372     9      5  2019
# 10442     2 stops                       No info  12352    24      3  2019
# 10443     2 stops   In-flight meal not included  11733     6      6  2019
# 10444    non-stop                       No info   4823     9      4  2019
# 10445    non-stop                       No info   4804    27      4  2019
# 10446      1 stop   In-flight meal not included  10262    12      6  2019
# 10447      1 stop   In-flight meal not included  11087    12      3  2019
# 10448     2 stops                       No info  21219     9      5  2019
# 10449      1 stop                       No info   9929    15      6  2019
# 10450     2 stops                       No info  11411    12      5  2019
# 10451    non-stop                       No info   3100     6      6  2019
# 10452      1 stop   In-flight meal not included  11087    12      3  2019
# 10453    non-stop                       No info   3100     9      6  2019
# 10454      1 stop                       No info   9794     1      5  2019
# 10455    non-stop  No check-in baggage included   3257    21      5  2019
# 10456    non-stop                       No info   4107     9      4  2019
# 10457    non-stop                       No info   4145    27      4  2019
# 10458    non-stop                       No info   7229    27      4  2019
# 10459    non-stop                       No info  12648     1      3  2019
# 10460     2 stops                       No info  11753     9      5  2019
#
#        Dep_Time_hour  Dep_Time_min  Arrival_Time_hour  Arrival_Time_min  \
# 0                 22            20                  1                10
# 1                  5            50                 13                15
# 2                  9            25                  4                25
# 3                 18             5                 23                30
# 4                 16            50                 21                35
# 5                  9             0                 11                25
# 6                 18            55                 10                25
# 7                  8             0                  5                 5
# 8                  8            55                 10                25
# 9                 11            25                 19                15
# 10                 9            45                 23                 0
# 11                20            20                 22                55
# 12                11            40                 13                55
# 13                21            10                  9                20
# 14                17            15                 19                50
# 15                16            40                 19                15
# 16                 8            45                 13                15
# 17                14             0                 12                35
# 18                20            15                 19                15
# 19                16             0                 12                35
# 20                14            10                 19                20
# 21                22             0                 13                20
# 22                 4             0                  6                50
# 23                18            55                 21                50
# 24                18            55                  8                15
# 25                21            25                 12                35
# 26                21            50                  3                35
# 27                 7             0                 12                55
# 28                 9            45                 12                35
# 29                 7             5                  9                20
# ...              ...           ...                ...               ...
# 10431              4            55                 12                35
# 10432              5            15                  6                50
# 10433             14             5                 12                 0
# 10434              5            55                  8                35
# 10435              2            55                  4                20
# 10436              7             0                  9                40
# 10437             20             0                  9                20
# 10438             11            10                 14                 5
# 10439             21             0                 23                50
# 10440             21            10                  0                 5
# 10441             13             0                 19                15
# 10442              9            25                  5                35
# 10443             19            30                 12                35
# 10444             18            55                 21                50
# 10445             15            15                 17                45
# 10446             18            15                 19                 0
# 10447             22            55                 20                20
# 10448             11            40                 19                 0
# 10449              8             0                 19                15
# 10450              5            50                 23                15
# 10451             21             5                 22                25
# 10452             20            35                 21                20
# 10453              6            20                  7                40
# 10454             10            20                 19                 0
# 10455              5            55                  8                35
# 10456             19            55                 22                25
# 10457             20            45                 23                20
# 10458              8            20                 11                20
# 10459             11            30                 14                10
# 10460             10            55                 19                15
#
#        Duration_hour  Duration_min
# 0                  2            50
# 1                  7            25
# 2                 19             0
# 3                  5            25
# 4                  4            45
# 5                  2            25
# 6                 15            30
# 7                 21             5
# 8                 25            30
# 9                  7            50
# 10                13            15
# 11                 2            35
# 12                 2            15
# 13                12            10
# 14                 2            35
# 15                26            35
# 16                 4            30
# 17                22            35
# 18                23             0
# 19                20            35
# 20                 5            10
# 21                15            20
# 22                 2            50
# 23                 2            55
# 24                13            20
# 25                15            10
# 26                 5            45
# 27                 5            55
# 28                 2            50
# 29                 2            15
# ...              ...           ...
# 10431              7            40
# 10432             25            35
# 10433             21            55
# 10434              2            40
# 10435              1            25
# 10436              2            40
# 10437             13            20
# 10438              2            55
# 10439              2            50
# 10440              2            55
# 10441              6            15
# 10442             20            10
# 10443             17             5
# 10444              2            55
# 10445              2            30
# 10446             24            45
# 10447             21            25
# 10448              7            20
# 10449             11            15
# 10450             17            25
# 10451              1            20
# 10452             24            45
# 10453              1            20
# 10454              8            40
# 10455              2            40
# 10456              2            30
# 10457              2            35
# 10458              3             0
# 10459              2            40
# 10460              8            20
#
# [10461 rows x 16 columns]

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()

# %%
pre_encoder_Airline = df['Airline'].value_counts()
pre_encoder_Airline
# Out:
# Jet Airways                          3700
# IndiGo                               2043
# Air India                            1693
# Multiple carriers                    1196
# SpiceJet                              815
# Vistara                               478
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64

# %%
df['Airline']=labelencoder.fit_transform(df['Airline'])

post_encoder_Airline = df['Airline'].value_counts()
post_encoder_Airline
# Out:
# 4     3700
# 3     2043
# 1     1693
# 6     1196
# 8      815
# 10     478
# 0      319
# 2      194
# 7       13
# 5        6
# 11       3
# 9        1
# Name: Airline, dtype: int64

# %%
df.head(3)
# Out:
#    Airline    Source Destination                  Route Total_Stops  \
# 0        3  Banglore   New Delhi              BLR → DEL    non-stop
# 1        1   Kolkata    Banglore  CCU → IXR → BBI → BLR     2 stops
# 2        4     Delhi      Cochin  DEL → LKO → BOM → COK     2 stops
#
#   Additional_Info  Price  date  month  year  Dep_Time_hour  Dep_Time_min  \
# 0         No info   3897    24      3  2019             22            20
# 1         No info   7662     1      5  2019              5            50
# 2         No info  13882     9      6  2019              9            25
#
#    Arrival_Time_hour  Arrival_Time_min  Duration_hour  Duration_min
# 0                  1                10              2            50
# 1                 13                15              7            25
# 2                  4                25             19             0

# %%
airline_dict={}

for i,j in zip(pre_encoder_Airline.keys(), post_encoder_Airline.keys()):
    airline_dict.update({i: j})

airline_dict
# Out:
# {'Jet Airways': 4,
#  'IndiGo': 3,
#  'Air India': 1,
#  'Multiple carriers': 6,
#  'SpiceJet': 8,
#  'Vistara': 10,
#  'Air Asia': 0,
#  'GoAir': 2,
#  'Multiple carriers Premium economy': 7,
#  'Jet Airways Business': 5,
#  'Vistara Premium economy': 11,
#  'Trujet': 9}

# %%
df.Source.unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
df.Destination.unique()

# New Delhi and Delhi should be the same
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
df['Destination'] = df['Destination'].replace("New Delhi", "Delhi")

# %%
df.Destination.unique()
# Out:
# array(['Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Hyderabad'],
#       dtype=object)

# %%
# Both Source and Destination features should have same enconding for repective cities
# sd_dict refers to Source_Destination Dictionary

sd_dict = {'Banglore':0, 'Kolkata':1, 'Delhi':2, 'Chennai':3, 'Mumbai':4,'Cochin':5, 'Hyderabad':6 }

# %%
df['Source'] = df['Source'].map(sd_dict)

# %%
df['Destination'] = df['Destination'].map(sd_dict)

# %%
df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %%
total_stop_dict = {'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4}

# %%
df['Total_Stops']=df['Total_Stops'].map(total_stop_dict)

# %%
df.Additional_Info.unique()

# 'No info' and 'No Info' should be same category
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
df['Additional_Info'] = df['Additional_Info'].replace('No Info', 'No info')

# %%
df.Additional_Info.unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
pre_encoder_Additional_Info = df['Additional_Info'].value_counts()
pre_encoder_Additional_Info
# Out:
# No info                         8184
# In-flight meal not included     1926
# No check-in baggage included     318
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# Red-eye flight                     1
# 1 Short layover                    1
# 2 Long layover                     1
# Name: Additional_Info, dtype: int64

# %%
df['Additional_Info']=labelencoder.fit_transform(df['Additional_Info'])

post_encoder_Additional_Info = df['Additional_Info'].value_counts()
post_encoder_Additional_Info
# Out:
# 7    8184
# 5    1926
# 6     318
# 0      19
# 4       7
# 3       4
# 2       1
# 1       1
# 8       1
# Name: Additional_Info, dtype: int64

# %%
Additional_Info_dict = {}

for i,j in zip(pre_encoder_Additional_Info.keys(), post_encoder_Additional_Info.keys()):
    Additional_Info_dict.update({i:j})
    
Additional_Info_dict
# Out:
# {'No info': 7,
#  'In-flight meal not included': 5,
#  'No check-in baggage included': 6,
#  '1 Long layover': 0,
#  'Change airports': 4,
#  'Business class': 3,
#  'Red-eye flight': 2,
#  '1 Short layover': 1,
#  '2 Long layover': 8}

# %%
df.head(3)
# Out:
#    Airline  Source  Destination                  Route  Total_Stops  \
# 0        3       0            2              BLR → DEL            0
# 1        1       1            0  CCU → IXR → BBI → BLR            2
# 2        4       2            5  DEL → LKO → BOM → COK            2
#
#    Additional_Info  Price  date  month  year  Dep_Time_hour  Dep_Time_min  \
# 0                7   3897    24      3  2019             22            20
# 1                7   7662     1      5  2019              5            50
# 2                7  13882     9      6  2019              9            25
#
#    Arrival_Time_hour  Arrival_Time_min  Duration_hour  Duration_min
# 0                  1                10              2            50
# 1                 13                15              7            25
# 2                  4                25             19             0

# %%
df.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Route', 'Total_Stops',
#        'Additional_Info', 'Price', 'date', 'month', 'year', 'Dep_Time_hour',
#        'Dep_Time_min', 'Arrival_Time_hour', 'Arrival_Time_min',
#        'Duration_hour', 'Duration_min'],
#       dtype='object')

# %%
df.drop(['Route', 'year'], axis =1, inplace = True)
df.reset_index(drop=True)
# Out:
#        Airline  Source  Destination  Total_Stops  Additional_Info  Price  \
# 0            3       0            2            0                7   3897
# 1            1       1            0            2                7   7662
# 2            4       2            5            2                7  13882
# 3            3       1            0            1                7   6218
# 4            3       0            2            1                7  13302
# 5            8       1            0            0                7   3873
# 6            4       0            2            1                5  11087
# 7            4       0            2            1                7  22270
# 8            4       0            2            1                5  11087
# 9            6       2            5            1                7   8625
# 10           1       2            5            1                7   8907
# 11           3       1            0            0                7   4174
# 12           1       3            1            0                7   4667
# 13           4       1            0            1                5   9663
# 14           3       1            0            0                7   4804
# 15           1       2            5            2                7  14011
# 16           8       2            5            1                7   5830
# 17           4       2            5            1                5  10262
# 18           1       2            5            2                7  13381
# 19           4       2            5            1                5  12898
# 20           2       2            5            1                7  19495
# 21           1       0            2            1                7   6955
# 22           3       0            2            0                7   3943
# 23           3       0            2            0                7   4823
# 24           4       1            0            1                5   7757
# 25           4       2            5            2                7  13292
# 26           3       2            5            1                7   8238
# 27           2       2            5            1                7   7682
# 28          10       0            2            0                7   4668
# 29          10       3            1            0                7   3687
# ...        ...     ...          ...          ...              ...    ...
# 10431        6       2            5            1                7  10678
# 10432        1       2            5            1                7   9790
# 10433        4       1            0            1                7  14388
# 10434        8       0            2            0                6   4319
# 10435        4       4            6            0                7   5678
# 10436       10       0            2            0                7   5613
# 10437        4       1            0            1                5   9663
# 10438        4       0            2            0                5   5769
# 10439       10       0            2            0                7   4668
# 10440       10       0            2            0                7   4878
# 10441        1       2            5            1                7   8372
# 10442        1       1            0            2                7  12352
# 10443        4       2            5            2                5  11733
# 10444        3       0            2            0                7   4823
# 10445        3       1            0            0                7   4804
# 10446        4       2            5            1                5  10262
# 10447        4       0            2            1                5  11087
# 10448        4       2            5            2                7  21219
# 10449        1       2            5            1                7   9929
# 10450        1       1            0            2                7  11411
# 10451        1       4            6            0                7   3100
# 10452        4       0            2            1                5  11087
# 10453        1       4            6            0                7   3100
# 10454        6       2            5            1                7   9794
# 10455        8       0            2            0                6   3257
# 10456        0       1            0            0                7   4107
# 10457        1       1            0            0                7   4145
# 10458        4       0            2            0                7   7229
# 10459       10       0            2            0                7  12648
# 10460        1       2            5            2                7  11753
#
#        date  month  Dep_Time_hour  Dep_Time_min  Arrival_Time_hour  \
# 0        24      3             22            20                  1
# 1         1      5              5            50                 13
# 2         9      6              9            25                  4
# 3        12      5             18             5                 23
# 4         1      3             16            50                 21
# 5        24      6              9             0                 11
# 6        12      3             18            55                 10
# 7         1      3              8             0                  5
# 8        12      3              8            55                 10
# 9        27      5             11            25                 19
# 10        1      6              9            45                 23
# 11       18      4             20            20                 22
# 12       24      6             11            40                 13
# 13        9      5             21            10                  9
# 14       24      4             17            15                 19
# 15        3      3             16            40                 19
# 16       15      4              8            45                 13
# 17       12      6             14             0                 12
# 18       12      6             20            15                 19
# 19       27      5             16             0                 12
# 20        6      3             14            10                 19
# 21       21      3             22             0                 13
# 22        3      4              4             0                  6
# 23        1      5             18            55                 21
# 24        6      5             18            55                  8
# 25        9      6             21            25                 12
# 26        1      6             21            50                  3
# 27       15      5              7             0                 12
# 28       18      6              9            45                 12
# 29       15      6              7             5                  9
# ...     ...    ...            ...           ...                ...
# 10431    27      6              4            55                 12
# 10432     9      3              5            15                  6
# 10433     1      5             14             5                 12
# 10434    12      6              5            55                  8
# 10435     3      5              2            55                  4
# 10436     6      4              7             0                  9
# 10437     6      5             20             0                  9
# 10438    18      6             11            10                 14
# 10439     1      5             21             0                 23
# 10440    21      3             21            10                  0
# 10441     9      5             13             0                 19
# 10442    24      3              9            25                  5
# 10443     6      6             19            30                 12
# 10444     9      4             18            55                 21
# 10445    27      4             15            15                 17
# 10446    12      6             18            15                 19
# 10447    12      3             22            55                 20
# 10448     9      5             11            40                 19
# 10449    15      6              8             0                 19
# 10450    12      5              5            50                 23
# 10451     6      6             21             5                 22
# 10452    12      3             20            35                 21
# 10453     9      6              6            20                  7
# 10454     1      5             10            20                 19
# 10455    21      5              5            55                  8
# 10456     9      4             19            55                 22
# 10457    27      4             20            45                 23
# 10458    27      4              8            20                 11
# 10459     1      3             11            30                 14
# 10460     9      5             10            55                 19
#
#        Arrival_Time_min  Duration_hour  Duration_min
# 0                    10              2            50
# 1                    15              7            25
# 2                    25             19             0
# 3                    30              5            25
# 4                    35              4            45
# 5                    25              2            25
# 6                    25             15            30
# 7                     5             21             5
# 8                    25             25            30
# 9                    15              7            50
# 10                    0             13            15
# 11                   55              2            35
# 12                   55              2            15
# 13                   20             12            10
# 14                   50              2            35
# 15                   15             26            35
# 16                   15              4            30
# 17                   35             22            35
# 18                   15             23             0
# 19                   35             20            35
# 20                   20              5            10
# 21                   20             15            20
# 22                   50              2            50
# 23                   50              2            55
# 24                   15             13            20
# 25                   35             15            10
# 26                   35              5            45
# 27                   55              5            55
# 28                   35              2            50
# 29                   20              2            15
# ...                 ...            ...           ...
# 10431                35              7            40
# 10432                50             25            35
# 10433                 0             21            55
# 10434                35              2            40
# 10435                20              1            25
# 10436                40              2            40
# 10437                20             13            20
# 10438                 5              2            55
# 10439                50              2            50
# 10440                 5              2            55
# 10441                15              6            15
# 10442                35             20            10
# 10443                35             17             5
# 10444                50              2            55
# 10445                45              2            30
# 10446                 0             24            45
# 10447                20             21            25
# 10448                 0              7            20
# 10449                15             11            15
# 10450                15             17            25
# 10451                25              1            20
# 10452                20             24            45
# 10453                40              1            20
# 10454                 0              8            40
# 10455                35              2            40
# 10456                25              2            30
# 10457                20              2            35
# 10458                20              3             0
# 10459                10              2            40
# 10460                15              8            20
#
# [10461 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['Airline', 'Source', 'Destination', 'Total_Stops', 'Additional_Info',
#        'Price', 'date', 'month', 'Dep_Time_hour', 'Dep_Time_min',
#        'Arrival_Time_hour', 'Arrival_Time_min', 'Duration_hour',
#        'Duration_min'],
#       dtype='object')

# %%
cols = ['date', 'month', 'Dep_Time_hour', 'Dep_Time_min', 'Arrival_Time_hour','Arrival_Time_min', 
        'Duration_hour','Duration_min','Airline','Source', 'Destination','Total_Stops', 'Additional_Info','Price']

df = df.reindex(cols, axis =1)

# %%
plt.figure(figsize = (12,10))
sns.heatmap(df.corr(), annot=True, cmap="RdYlGn")
plt.show()

# %%
detail_info(df)
# Out:
#                   data_type  unique_val  duplicate_val  missing_val  \
# date                  int32          10              2            0
# month                 int32           4              2            0
# Dep_Time_hour         int32          24              2            0
# Dep_Time_min          int32          12              2            0
# Arrival_Time_hour     int32          24              2            0
# Arrival_Time_min      int32          12              2            0
# Duration_hour         int32          43              2            0
# Duration_min          int32          12              2            0
# Airline               int32          12              2            0
# Source                int64           5              2            0
# Destination           int64           5              2            0
# Total_Stops           int64           5              2            0
# Additional_Info       int32           9              2            0
# Price                 int64        1870              2            0
#
#                    missing_val_%
# date                         0.0
# month                        0.0
# Dep_Time_hour                0.0
# Dep_Time_min                 0.0
# Arrival_Time_hour            0.0
# Arrival_Time_min             0.0
# Duration_hour                0.0
# Duration_min                 0.0
# Airline                      0.0
# Source                       0.0
# Destination                  0.0
# Total_Stops                  0.0
# Additional_Info              0.0
# Price                        0.0

# %%
df.drop_duplicates(keep='first', inplace=True)
df.reset_index(drop=True)
# Out:
#        date  month  Dep_Time_hour  Dep_Time_min  Arrival_Time_hour  \
# 0        24      3             22            20                  1
# 1         1      5              5            50                 13
# 2         9      6              9            25                  4
# 3        12      5             18             5                 23
# 4         1      3             16            50                 21
# 5        24      6              9             0                 11
# 6        12      3             18            55                 10
# 7         1      3              8             0                  5
# 8        12      3              8            55                 10
# 9        27      5             11            25                 19
# 10        1      6              9            45                 23
# 11       18      4             20            20                 22
# 12       24      6             11            40                 13
# 13        9      5             21            10                  9
# 14       24      4             17            15                 19
# 15        3      3             16            40                 19
# 16       15      4              8            45                 13
# 17       12      6             14             0                 12
# 18       12      6             20            15                 19
# 19       27      5             16             0                 12
# 20        6      3             14            10                 19
# 21       21      3             22             0                 13
# 22        3      4              4             0                  6
# 23        1      5             18            55                 21
# 24        6      5             18            55                  8
# 25        9      6             21            25                 12
# 26        1      6             21            50                  3
# 27       15      5              7             0                 12
# 28       18      6              9            45                 12
# 29       15      6              7             5                  9
# ...     ...    ...            ...           ...                ...
# 10429    27      6              4            55                 12
# 10430     9      3              5            15                  6
# 10431     1      5             14             5                 12
# 10432    12      6              5            55                  8
# 10433     3      5              2            55                  4
# 10434     6      4              7             0                  9
# 10435     6      5             20             0                  9
# 10436    18      6             11            10                 14
# 10437     1      5             21             0                 23
# 10438    21      3             21            10                  0
# 10439     9      5             13             0                 19
# 10440    24      3              9            25                  5
# 10441     6      6             19            30                 12
# 10442     9      4             18            55                 21
# 10443    27      4             15            15                 17
# 10444    12      6             18            15                 19
# 10445    12      3             22            55                 20
# 10446     9      5             11            40                 19
# 10447    15      6              8             0                 19
# 10448    12      5              5            50                 23
# 10449     6      6             21             5                 22
# 10450    12      3             20            35                 21
# 10451     9      6              6            20                  7
# 10452     1      5             10            20                 19
# 10453    21      5              5            55                  8
# 10454     9      4             19            55                 22
# 10455    27      4             20            45                 23
# 10456    27      4              8            20                 11
# 10457     1      3             11            30                 14
# 10458     9      5             10            55                 19
#
#        Arrival_Time_min  Duration_hour  Duration_min  Airline  Source  \
# 0                    10              2            50        3       0
# 1                    15              7            25        1       1
# 2                    25             19             0        4       2
# 3                    30              5            25        3       1
# 4                    35              4            45        3       0
# 5                    25              2            25        8       1
# 6                    25             15            30        4       0
# 7                     5             21             5        4       0
# 8                    25             25            30        4       0
# 9                    15              7            50        6       2
# 10                    0             13            15        1       2
# 11                   55              2            35        3       1
# 12                   55              2            15        1       3
# 13                   20             12            10        4       1
# 14                   50              2            35        3       1
# 15                   15             26            35        1       2
# 16                   15              4            30        8       2
# 17                   35             22            35        4       2
# 18                   15             23             0        1       2
# 19                   35             20            35        4       2
# 20                   20              5            10        2       2
# 21                   20             15            20        1       0
# 22                   50              2            50        3       0
# 23                   50              2            55        3       0
# 24                   15             13            20        4       1
# 25                   35             15            10        4       2
# 26                   35              5            45        3       2
# 27                   55              5            55        2       2
# 28                   35              2            50       10       0
# 29                   20              2            15       10       3
# ...                 ...            ...           ...      ...     ...
# 10429                35              7            40        6       2
# 10430                50             25            35        1       2
# 10431                 0             21            55        4       1
# 10432                35              2            40        8       0
# 10433                20              1            25        4       4
# 10434                40              2            40       10       0
# 10435                20             13            20        4       1
# 10436                 5              2            55        4       0
# 10437                50              2            50       10       0
# 10438                 5              2            55       10       0
# 10439                15              6            15        1       2
# 10440                35             20            10        1       1
# 10441                35             17             5        4       2
# 10442                50              2            55        3       0
# 10443                45              2            30        3       1
# 10444                 0             24            45        4       2
# 10445                20             21            25        4       0
# 10446                 0              7            20        4       2
# 10447                15             11            15        1       2
# 10448                15             17            25        1       1
# 10449                25              1            20        1       4
# 10450                20             24            45        4       0
# 10451                40              1            20        1       4
# 10452                 0              8            40        6       2
# 10453                35              2            40        8       0
# 10454                25              2            30        0       1
# 10455                20              2            35        1       1
# 10456                20              3             0        4       0
# 10457                10              2            40       10       0
# 10458                15              8            20        1       2
#
#        Destination  Total_Stops  Additional_Info  Price
# 0                2            0                7   3897
# 1                0            2                7   7662
# 2                5            2                7  13882
# 3                0            1                7   6218
# 4                2            1                7  13302
# 5                0            0                7   3873
# 6                2            1                5  11087
# 7                2            1                7  22270
# 8                2            1                5  11087
# 9                5            1                7   8625
# 10               5            1                7   8907
# 11               0            0                7   4174
# 12               1            0                7   4667
# 13               0            1                5   9663
# 14               0            0                7   4804
# 15               5            2                7  14011
# 16               5            1                7   5830
# 17               5            1                5  10262
# 18               5            2                7  13381
# 19               5            1                5  12898
# 20               5            1                7  19495
# 21               2            1                7   6955
# 22               2            0                7   3943
# 23               2            0                7   4823
# 24               0            1                5   7757
# 25               5            2                7  13292
# 26               5            1                7   8238
# 27               5            1                7   7682
# 28               2            0                7   4668
# 29               1            0                7   3687
# ...            ...          ...              ...    ...
# 10429            5            1                7  10678
# 10430            5            1                7   9790
# 10431            0            1                7  14388
# 10432            2            0                6   4319
# 10433            6            0                7   5678
# 10434            2            0                7   5613
# 10435            0            1                5   9663
# 10436            2            0                5   5769
# 10437            2            0                7   4668
# 10438            2            0                7   4878
# 10439            5            1                7   8372
# 10440            0            2                7  12352
# 10441            5            2                5  11733
# 10442            2            0                7   4823
# 10443            0            0                7   4804
# 10444            5            1                5  10262
# 10445            2            1                5  11087
# 10446            5            2                7  21219
# 10447            5            1                7   9929
# 10448            0            2                7  11411
# 10449            6            0                7   3100
# 10450            2            1                5  11087
# 10451            6            0                7   3100
# 10452            5            1                7   9794
# 10453            2            0                6   3257
# 10454            0            0                7   4107
# 10455            0            0                7   4145
# 10456            2            0                7   7229
# 10457            2            0                7  12648
# 10458            5            2                7  11753
#
# [10459 rows x 14 columns]

# %%
for feature in df.columns:
    df[feature] = df[feature].astype('int64')

# %%
detail_info(df)
# Out:
#                   data_type  unique_val  duplicate_val  missing_val  \
# date                  int64          10              0            0
# month                 int64           4              0            0
# Dep_Time_hour         int64          24              0            0
# Dep_Time_min          int64          12              0            0
# Arrival_Time_hour     int64          24              0            0
# Arrival_Time_min      int64          12              0            0
# Duration_hour         int64          43              0            0
# Duration_min          int64          12              0            0
# Airline               int64          12              0            0
# Source                int64           5              0            0
# Destination           int64           5              0            0
# Total_Stops           int64           5              0            0
# Additional_Info       int64           9              0            0
# Price                 int64        1870              0            0
#
#                    missing_val_%
# date                         0.0
# month                        0.0
# Dep_Time_hour                0.0
# Dep_Time_min                 0.0
# Arrival_Time_hour            0.0
# Arrival_Time_min             0.0
# Duration_hour                0.0
# Duration_min                 0.0
# Airline                      0.0
# Source                       0.0
# Destination                  0.0
# Total_Stops                  0.0
# Additional_Info              0.0
# Price                        0.0

# %%
sns.distplot(df['Price'])

# %%
sns.boxplot(df['Price'])

# %%
len(df[df['Price']>30000])
# Out:
# 24

# %%
df['Price']=np.where(df['Price']>=30000,df['Price'].median(),df['Price'])

# %%
df.columns
# Out:
# Index(['date', 'month', 'Dep_Time_hour', 'Dep_Time_min', 'Arrival_Time_hour',
#        'Arrival_Time_min', 'Duration_hour', 'Duration_min', 'Airline',
#        'Source', 'Destination', 'Total_Stops', 'Additional_Info', 'Price'],
#       dtype='object')

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.20, random_state=42)

# %%
X_train.shape
# Out:
# (8367, 13)

# %%
X_test.shape
# Out:
# (2092, 13)

# %%
X_test.shape
# Out:
# (2092, 13)

# %%
# Important Features using ExtraTreesRegressor

from sklearn.ensemble import ExtraTreesRegressor
xtr = ExtraTreesRegressor()
xtr.fit(X_train,y_train)
# Out:
# ExtraTreesRegressor()

# %%
print(xtr.feature_importances_)
# Out:
# [0.10058388 0.06881682 0.02777265 0.02444239 0.02521079 0.02104662
#  0.1560282  0.01865548 0.13818727 0.02496516 0.01979259 0.32698926
#  0.04750888]

# %%
print(type(xtr.feature_importances_))
# Out:
# <class 'numpy.ndarray'>

# %%
np.sort(xtr.feature_importances_)
# Out:
# array([0.01865548, 0.01979259, 0.02104662, 0.02444239, 0.02496516,
#        0.02521079, 0.02777265, 0.04750888, 0.06881682, 0.10058388,
#        0.13818727, 0.1560282 , 0.32698926])

# %%
(pd.Series(np.sort(xtr.feature_importances_), index=X_train.columns).plot(kind='barh'))

# Addiional_Info is most important feature for dependant feature Price as it has the information of Business Class

# %%
X_train.columns
# Out:
# Index(['date', 'month', 'Dep_Time_hour', 'Dep_Time_min', 'Arrival_Time_hour',
#        'Arrival_Time_min', 'Duration_hour', 'Duration_min', 'Airline',
#        'Source', 'Destination', 'Total_Stops', 'Additional_Info'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet, RidgeCV,LassoCV,ElasticNetCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
metrics = pd.DataFrame(index=['Train_Score', 'Test_Score','CV_Score', 
                              'Train_Score_Tuned', 'Test_Score_Tuned', 
                              'MAE_Tuned', 'MSE_Tuned', 'RMSE_Tuned'],
                       columns=['LinearReg','LR_Lasso', 'LR_Ridge', 'ElasticNet','KNeighborsReg','DecisionTreeReg', 'RandomForestReg'])

# %%
metrics
# Out:
#                   LinearReg LR_Lasso LR_Ridge ElasticNet KNeighborsReg  \
# Train_Score             NaN      NaN      NaN        NaN           NaN
# Test_Score              NaN      NaN      NaN        NaN           NaN
# CV_Score                NaN      NaN      NaN        NaN           NaN
# Train_Score_Tuned       NaN      NaN      NaN        NaN           NaN
# Test_Score_Tuned        NaN      NaN      NaN        NaN           NaN
# MAE_Tuned               NaN      NaN      NaN        NaN           NaN
# MSE_Tuned               NaN      NaN      NaN        NaN           NaN
# RMSE_Tuned              NaN      NaN      NaN        NaN           NaN
#
#                   DecisionTreeReg RandomForestReg
# Train_Score                   NaN             NaN
# Test_Score                    NaN             NaN
# CV_Score                      NaN             NaN
# Train_Score_Tuned             NaN             NaN
# Test_Score_Tuned              NaN             NaN
# MAE_Tuned                     NaN             NaN
# MSE_Tuned                     NaN             NaN
# RMSE_Tuned                    NaN             NaN

# %%
models = []

models.append(('LinearReg',LinearRegression()))
models.append(('LR_Lasso',Lasso()))
models.append(('LR_Ridge',Ridge()))
models.append(('ElasticNet',ElasticNet()))

models.append(('KNeighborsReg',KNeighborsRegressor()))
models.append(('DecisionTreeReg',DecisionTreeRegressor()))
models.append(('RandomForestReg',RandomForestRegressor()))

# %%
models
# Out:
# [('LinearReg', LinearRegression()),
#  ('LR_Lasso', Lasso()),
#  ('LR_Ridge', Ridge()),
#  ('ElasticNet', ElasticNet()),
#  ('KNeighborsReg', KNeighborsRegressor()),
#  ('DecisionTreeReg', DecisionTreeRegressor()),
#  ('RandomForestReg', RandomForestRegressor())]

# %%
for name, model in models:
    temp_model = model.fit(X_train, y_train)
    result = temp_model.score(X_train, y_train)
    metrics.loc['Train_Score', name] = round(result*100,4)
  
    y_pred = temp_model.predict(X_test)
    metrics.loc['Test_Score', name] = round(r2_score(y_test,y_pred)*100,4)

    cv_score = cross_val_score(model, X_train, y_train, cv = 5, n_jobs=-1, scoring ='r2')
    metrics.loc['CV_Score', name] = round(cv_score.mean()*100,4)                                       
    print(f"{name:{13}} {cv_score} {cv_score.mean():{18}} {cv_score.std():{18}}")
# Out:
# LinearReg     [0.47640205 0.49258576 0.48156121 0.48605938 0.45685307] 0.47869229271337377 0.012146851129489105
# LR_Lasso      [0.47647821 0.49258034 0.48156903 0.48599972 0.45684586] 0.4786946316555378 0.01213854115868339
# LR_Ridge      [0.4764164  0.49258802 0.48155438 0.48605367 0.45684945] 0.4786923831759706 0.012147115592675452
# ElasticNet    [0.41825857 0.42586628 0.41143854 0.41327403 0.3872235 ] 0.4112121865683763 0.012993486345295206
# KNeighborsReg [0.62767313 0.64505669 0.62376548 0.59486063 0.63192956] 0.6246570979797308 0.01653332028372965
# DecisionTreeReg [0.80748489 0.84529255 0.84327066 0.84129411 0.80633176] 0.8287347953304736 0.017869758053752426
# RandomForestReg [0.87353648 0.89064154 0.89952698 0.90046145 0.89325227]  0.891483744114604 0.00970808137105028

# %%
metrics
# Out:
#                   LinearReg LR_Lasso LR_Ridge ElasticNet KNeighborsReg  \
# Train_Score         48.1224  48.1223  48.1224    41.3618       77.9363
# Test_Score            47.51  47.5087  47.5106    40.8835       63.4804
# CV_Score            47.8692  47.8695  47.8692    41.1212       62.4657
# Train_Score_Tuned       NaN      NaN      NaN        NaN           NaN
# Test_Score_Tuned        NaN      NaN      NaN        NaN           NaN
# MAE_Tuned               NaN      NaN      NaN        NaN           NaN
# MSE_Tuned               NaN      NaN      NaN        NaN           NaN
# RMSE_Tuned              NaN      NaN      NaN        NaN           NaN
#
#                   DecisionTreeReg RandomForestReg
# Train_Score               99.6077         98.2969
# Test_Score                80.6575         90.1271
# CV_Score                  82.8735         89.1484
# Train_Score_Tuned             NaN             NaN
# Test_Score_Tuned              NaN             NaN
# MAE_Tuned                     NaN             NaN
# MSE_Tuned                     NaN             NaN
# RMSE_Tuned                    NaN             NaN

# %%
lassocv = LassoCV(alphas = None, cv=10, max_iter = 200000, random_state=42)
lassocv.fit(X_train, y_train)
# Out:
# LassoCV(cv=10, max_iter=200000, random_state=42)

# %%
lassocv.alpha_
# Out:
# 19.746845097073518

# %%
lasso_lr = Lasso(alpha= lassocv.alpha_)
lasso_lr.fit(X_train, y_train)
metrics.loc['Train_Score_Tuned', 'LR_Lasso'] = round(lasso_lr.score(X_train, y_train)*100,4)

# %%
y_pred_lasso = lasso_lr.predict(X_test)

metrics.loc['Test_Score_Tuned', 'LR_Lasso'] = round(r2_score(y_test, y_pred_lasso)*100,4)
metrics.loc['MAE_Tuned', 'LR_Lasso'] = mean_absolute_error(y_test, y_pred_lasso)
metrics.loc['MSE_Tuned', 'LR_Lasso'] = mean_squared_error(y_test, y_pred_lasso)
metrics.loc['RMSE_Tuned', 'LR_Lasso'] = np.sqrt(mean_squared_error(y_test, y_pred_lasso))

# %%
metrics
# Out:
#                   LinearReg     LR_Lasso LR_Ridge ElasticNet KNeighborsReg  \
# Train_Score         48.1224      48.1223  48.1224    41.3618       77.9363
# Test_Score            47.51      47.5087  47.5106    40.8835       63.4804
# CV_Score            47.8692      47.8695  47.8692    41.1212       62.4657
# Train_Score_Tuned       NaN       48.102      NaN        NaN           NaN
# Test_Score_Tuned        NaN      47.4654      NaN        NaN           NaN
# MAE_Tuned               NaN      2338.54      NaN        NaN           NaN
# MSE_Tuned               NaN  9.55754e+06      NaN        NaN           NaN
# RMSE_Tuned              NaN      3091.53      NaN        NaN           NaN
#
#                   DecisionTreeReg RandomForestReg
# Train_Score               99.6077         98.2969
# Test_Score                80.6575         90.1271
# CV_Score                  82.8735         89.1484
# Train_Score_Tuned             NaN             NaN
# Test_Score_Tuned              NaN             NaN
# MAE_Tuned                     NaN             NaN
# MSE_Tuned                     NaN             NaN
# RMSE_Tuned                    NaN             NaN

# %%
ridgecv = RidgeCV(alphas = np.arange(.1,10,100), cv=10)
ridgecv.fit(X_train, y_train)
ridgecv.alpha_
# Out:
# 0.1

# %%
ridge_lr = Ridge(alpha=ridgecv.alpha_)
ridge_lr.fit(X_train, y_train)
metrics.loc['Train_Score_Tuned', 'LR_Ridge'] = round(ridge_lr.score(X_train,y_train)*100,4)

# %%
y_pred_rg = ridge_lr.predict(X_test)

metrics.loc['Test_Score_Tuned', 'LR_Ridge'] = round(r2_score(y_test, y_pred_rg)*100,4)
metrics.loc['MAE_Tuned', 'LR_Ridge'] = mean_absolute_error(y_test, y_pred_rg)
metrics.loc['MSE_Tuned', 'LR_Ridge'] = mean_squared_error(y_test, y_pred_rg)
metrics.loc['RMSE_Tuned', 'LR_Ridge'] = np.sqrt(mean_squared_error(y_test, y_pred_rg))

# %%
metrics
# Out:
#                   LinearReg     LR_Lasso     LR_Ridge ElasticNet  \
# Train_Score         48.1224      48.1223      48.1224    41.3618
# Test_Score            47.51      47.5087      47.5106    40.8835
# CV_Score            47.8692      47.8695      47.8692    41.1212
# Train_Score_Tuned       NaN       48.102      48.1224        NaN
# Test_Score_Tuned        NaN      47.4654      47.5101        NaN
# MAE_Tuned               NaN      2338.54      2340.56        NaN
# MSE_Tuned               NaN  9.55754e+06  9.54941e+06        NaN
# RMSE_Tuned              NaN      3091.53      3090.21        NaN
#
#                   KNeighborsReg DecisionTreeReg RandomForestReg
# Train_Score             77.9363         99.6077         98.2969
# Test_Score              63.4804         80.6575         90.1271
# CV_Score                62.4657         82.8735         89.1484
# Train_Score_Tuned           NaN             NaN             NaN
# Test_Score_Tuned            NaN             NaN             NaN
# MAE_Tuned                   NaN             NaN             NaN
# MSE_Tuned                   NaN             NaN             NaN
# RMSE_Tuned                  NaN             NaN             NaN

# %%
# Theory Lambda = Alpha
# Thoery Alpha = l1_ratio

elastic = ElasticNetCV(alphas = None, l1_ratio= np.arange(0.1,1.1,.1), cv =10)
elastic.fit(X_train, y_train)
elastic.alpha_
# Out:
# 19.746845097073518

# %%
elastic.l1_ratio_
# Out:
# 1.0

# %%
elastic_lr = ElasticNet(alpha = elastic.alpha_, l1_ratio = elastic.l1_ratio_)
elastic_lr.fit(X_train, y_train)
metrics.loc['Train_Score_Tuned', 'ElasticNet'] = round(elastic_lr.score(X_train, y_train)*100,4)

# %%
y_pred_elastic = elastic_lr.predict(X_test)

metrics.loc['Test_Score_Tuned', 'ElasticNet'] = round(r2_score(y_test, y_pred_elastic)*100,4)
metrics.loc['MAE_Tuned', 'ElasticNet'] = mean_absolute_error(y_test, y_pred_elastic)
metrics.loc['MSE_Tuned', 'ElasticNet'] = mean_squared_error(y_test, y_pred_elastic)
metrics.loc['RMSE_Tuned', 'ElasticNet'] = np.sqrt(mean_squared_error(y_test, y_pred_elastic))

# %%
metrics
# Out:
#                   LinearReg     LR_Lasso     LR_Ridge   ElasticNet  \
# Train_Score         48.1224      48.1223      48.1224      41.3618
# Test_Score            47.51      47.5087      47.5106      40.8835
# CV_Score            47.8692      47.8695      47.8692      41.1212
# Train_Score_Tuned       NaN       48.102      48.1224       48.102
# Test_Score_Tuned        NaN      47.4654      47.5101      47.4654
# MAE_Tuned               NaN      2338.54      2340.56      2338.54
# MSE_Tuned               NaN  9.55754e+06  9.54941e+06  9.55754e+06
# RMSE_Tuned              NaN      3091.53      3090.21      3091.53
#
#                   KNeighborsReg DecisionTreeReg RandomForestReg
# Train_Score             77.9363         99.6077         98.2969
# Test_Score              63.4804         80.6575         90.1271
# CV_Score                62.4657         82.8735         89.1484
# Train_Score_Tuned           NaN             NaN             NaN
# Test_Score_Tuned            NaN             NaN             NaN
# MAE_Tuned                   NaN             NaN             NaN
# MSE_Tuned                   NaN             NaN             NaN
# RMSE_Tuned                  NaN             NaN             NaN

# %%
from sklearn.model_selection import GridSearchCV

# %%
# KNeighbor

param_grid = {'n_neighbors': np.arange(2,25,1),
              'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
              'weights' : ['uniform', 'distance'],
              'leaf_size': [10,20,30],
              'p' : [1,2],
              'metric': ['minkowski'],
              'n_jobs' : [-1]
                }


kn_model = GridSearchCV(KNeighborsRegressor(), param_grid, cv =3, scoring='accuracy')
kn_model.fit(X_train,y_train)
kn_model.best_params_

# %%
#{'algorithm': 'auto', 'leaf_size': 10, 'metric': 'minkowski', 'n_jobs': -1, 'n_neighbors': 2, 'p': 1, 'weights': 'uniform'}#

# %%
kn_model = KNeighborsRegressor(n_neighbors= 2, algorithm= 'auto', weights= 'uniform', leaf_size= 10, 
                               p =1 , metric= 'minkowski', n_jobs = -1)
kn_model.fit(X_train,y_train)
y_pred_kn = kn_model.predict(X_test)
r2_score(y_test, y_pred_kn)
# Out:
# 0.6950139833622448

# %%
metrics.loc['Train_Score_Tuned', 'KNeighborsReg'] = round(kn_model.score(X_train,  y_train)*100,4)
metrics.loc['Test_Score_Tuned' , 'KNeighborsReg'] = round(r2_score(y_test,y_pred_kn)*100,4)

metrics.loc['MAE_Tuned', 'KNeighborsReg'] = mean_absolute_error(y_test, y_pred_kn)
metrics.loc['MSE_Tuned', 'KNeighborsReg'] = mean_squared_error(y_test, y_pred_kn)
metrics.loc['RMSE_Tuned', 'KNeighborsReg'] = np.sqrt(mean_squared_error(y_test, y_pred_kn))

metrics
# Out:
#                   LinearReg     LR_Lasso     LR_Ridge   ElasticNet  \
# Train_Score         48.1224      48.1223      48.1224      41.3618
# Test_Score            47.51      47.5087      47.5106      40.8835
# CV_Score            47.8692      47.8695      47.8692      41.1212
# Train_Score_Tuned       NaN       48.102      48.1224       48.102
# Test_Score_Tuned        NaN      47.4654      47.5101      47.4654
# MAE_Tuned               NaN      2338.54      2340.56      2338.54
# MSE_Tuned               NaN  9.55754e+06  9.54941e+06  9.55754e+06
# RMSE_Tuned              NaN      3091.53      3090.21      3091.53
#
#                   KNeighborsReg DecisionTreeReg RandomForestReg
# Train_Score             77.9363         99.6077         98.2969
# Test_Score              63.4804         80.6575         90.1271
# CV_Score                62.4657         82.8735         89.1484
# Train_Score_Tuned       90.0492             NaN             NaN
# Test_Score_Tuned        69.5014             NaN             NaN
# MAE_Tuned               1460.28             NaN             NaN
# MSE_Tuned           5.54856e+06             NaN             NaN
# RMSE_Tuned              2355.54             NaN             NaN

# %%
# Decision Tree

param_grid = {'criterion' : ['squared_error', 'absolute_error'],
              'splitter': ['best', 'random'],
              'max_depth' : [2,4,6,8,10],
              'min_samples_leaf': np.arange(1,10,1),
              'max_features' : [2,4,6,8,10],
              'random_state' : [42]
             } 


dt_model = GridSearchCV(DecisionTreeRegressor(), param_grid, cv =5, scoring='r2')
dt_model.fit(X_train,y_train)
dt_model.best_params_

# %%
#{'criterion': 'squared_error', 'max_depth': 10, 'max_features': 10, 'min_samples_leaf': 5, 'random_state': 42, 'splitter': 'best'}

# %%
dt_model = DecisionTreeRegressor(criterion= 'squared_error', max_depth= 10, max_features= 10, min_samples_leaf= 5, splitter = 'best', random_state=42)
dt_model.fit(X_train,y_train)
y_pred_dt = dt_model.predict(X_test)
r2_score(y_test, y_pred_dt)
# Out:
# 0.8423923833102058

# %%
metrics.loc['Train_Score_Tuned', 'DecisionTreeReg'] = round(dt_model.score(X_train, y_train)*100,4)
metrics.loc['Test_Score_Tuned' , 'DecisionTreeReg'] = round(r2_score(y_test,y_pred_dt)*100,4)

metrics.loc['MAE_Tuned', 'DecisionTreeReg'] = mean_absolute_error(y_test, y_pred_dt)
metrics.loc['MSE_Tuned', 'DecisionTreeReg'] = mean_squared_error(y_test, y_pred_dt)
metrics.loc['RMSE_Tuned', 'DecisionTreeReg'] = np.sqrt(mean_squared_error(y_test, y_pred_dt))

metrics
# Out:
#                   LinearReg     LR_Lasso     LR_Ridge   ElasticNet  \
# Train_Score         48.1224      48.1223      48.1224      41.3618
# Test_Score            47.51      47.5087      47.5106      40.8835
# CV_Score            47.8692      47.8695      47.8692      41.1212
# Train_Score_Tuned       NaN       48.102      48.1224       48.102
# Test_Score_Tuned        NaN      47.4654      47.5101      47.4654
# MAE_Tuned               NaN      2338.54      2340.56      2338.54
# MSE_Tuned               NaN  9.55754e+06  9.54941e+06  9.55754e+06
# RMSE_Tuned              NaN      3091.53      3090.21      3091.53
#
#                   KNeighborsReg DecisionTreeReg RandomForestReg
# Train_Score             77.9363         99.6077         98.2969
# Test_Score              63.4804         80.6575         90.1271
# CV_Score                62.4657         82.8735         89.1484
# Train_Score_Tuned       90.0492         88.8799             NaN
# Test_Score_Tuned        69.5014         84.2392             NaN
# MAE_Tuned               1460.28         992.977             NaN
# MSE_Tuned           5.54856e+06     2.86733e+06             NaN
# RMSE_Tuned              2355.54         1693.32             NaN

# %%
# Random Forest

param_grid = {'criterion' : ['squared_error', 'absolute_error'],
        'n_estimators' : [10,100,200,300],
        'max_depth' : [5,10,15,20],
        'max_features':  [5,6,7,8,9,10],
        'min_samples_leaf': [5,6,7,8,9,10],
        'oob_score' : [True,False],
        'n_jobs': [-1],
        'random_state': [42]
        }

rf_model = GridSearchCV(RandomForestRegressor(), param_grid, scoring='accuracy')
rf_model.fit(X_train,y_train)
rf_model.best_params_

# %%
"""{'criterion': 'squared_error', 'max_depth': 5, 'max_features': 5, 'max_leaf_nodes': 5, 'n_estimators': 10,
                 'n_jobs': -1, 'oob_score': True, 'random_state': 42}
                 
"""
# Out:
# "{'criterion': 'squared_error', 'max_depth': 5, 'max_features': 5, 'max_leaf_nodes': 5, 'n_estimators': 10,\n                 'n_jobs': -1, 'oob_score': True, 'random_state': 42}\n                 \n"

# %%
rf_model = RandomForestRegressor(criterion= 'squared_error', n_estimators= 300, max_depth= 15, max_features= 9, min_samples_leaf= 10, oob_score=False)
rf_model.fit(X_train,y_train)
y_pred_rf = rf_model.predict(X_test)
r2_score(y_test, y_pred_rf)
# Out:
# 0.8814637774736551

# %%
metrics.loc['Train_Score_Tuned', 'RandomForestReg'] = round(rf_model.score(X_train, y_train)*100,4)
metrics.loc['Test_Score_Tuned' , 'RandomForestReg'] = round(r2_score(y_test,y_pred_rf)*100,4)

metrics.loc['MAE_Tuned', 'RandomForestReg'] = mean_absolute_error(y_test, y_pred_rf)
metrics.loc['MSE_Tuned', 'RandomForestReg'] = mean_squared_error(y_test, y_pred_rf)
metrics.loc['RMSE_Tuned', 'RandomForestReg'] = np.sqrt(mean_squared_error(y_test, y_pred_rf))

metrics
# Out:
#                   LinearReg     LR_Lasso     LR_Ridge   ElasticNet  \
# Train_Score         48.1224      48.1223      48.1224      41.3618
# Test_Score            47.51      47.5087      47.5106      40.8835
# CV_Score            47.8692      47.8695      47.8692      41.1212
# Train_Score_Tuned       NaN       48.102      48.1224       48.102
# Test_Score_Tuned        NaN      47.4654      47.5101      47.4654
# MAE_Tuned               NaN      2338.54      2340.56      2338.54
# MSE_Tuned               NaN  9.55754e+06  9.54941e+06  9.55754e+06
# RMSE_Tuned              NaN      3091.53      3090.21      3091.53
#
#                   KNeighborsReg DecisionTreeReg RandomForestReg
# Train_Score             77.9363         99.6077         98.2969
# Test_Score              63.4804         80.6575         90.1271
# CV_Score                62.4657         82.8735         89.1484
# Train_Score_Tuned       90.0492         88.8799         89.7109
# Test_Score_Tuned        69.5014         84.2392         88.1464
# MAE_Tuned               1460.28         992.977         898.094
# MSE_Tuned           5.54856e+06     2.86733e+06     2.15651e+06
# RMSE_Tuned              2355.54         1693.32         1468.51

# %%
pickle.dump(rf_model, open('FlightPrice.pkl','wb'))
